# %% [markdown]
# # Evaluation Results

# %% [markdown]
# Import packages.

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# Specify the configuration to read results for.

# %%
num_models = 4
opt_metric = "mse"
# opt_metric = "mae"
num_windows = 1
ensemble = "SLSQPEnsemble"

alias = f"{ensemble}_{num_models}-models_opt-{opt_metric}_{num_windows}-windows"

# %% [markdown]
# Read all of the configuration's CSV files into a single DataFrame and save the aggregated results.

# %%
input_path = Path(f"../results/{alias}/")
csv_files = list(input_path.rglob("*.csv"))

df = pd.concat((pd.read_csv(f).tail(1) for f in csv_files), ignore_index=True)
print(f"df shape: {df.shape}")

output_path = Path(f"../results/all_results/{alias}") / "all_results.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(output_path, index=False)
print(f"Saved aggregatted results to {output_path}")

df.head()
# Out:
# df shape: (97, 15)
# Saved aggregatted results to ../results/all_results/SLSQPEnsemble_4-models_opt-mse_1-windows/all_results.csv
#                  dataset                                     model  \
# 0       hospital/M/short  SLSQPEnsemble_4-models_opt-mse_1-windows
# 1    bizitobs_l2c/H/long  SLSQPEnsemble_4-models_opt-mse_1-windows
# 2   bizitobs_l2c/H/short  SLSQPEnsemble_4-models_opt-mse_1-windows
# 3  bizitobs_l2c/H/medium  SLSQPEnsemble_4-models_opt-mse_1-windows
# 4  bizitobs_l2c/5T/short  SLSQPEnsemble_4-models_opt-mse_1-windows
#
#    eval_metrics/MSE[mean]  eval_metrics/MSE[0.5]  eval_metrics/MAE[0.5]  \
# 0             2892.351140            2892.351140              18.071333
# 1              101.507623             101.507623               5.805044
# 2               48.038459              48.038459               4.211857
# 3               71.841403              71.841403               4.985829
# 4               14.169957              14.169957               2.347573
#
#    eval_metrics/MASE[0.5]  eval_metrics/MAPE[0.5]  eval_metrics/sMAPE[0.5]  \
# 0                0.765593                0.192416                 0.174045
# 1                0.615259                0.710946                 0.809245
# 2                0.414767                0.388088                 0.589606
# 3                0.500909                0.552815                 0.787636
# 4                0.245052                0.144002                 0.186917
#
#    eval_metrics/MSIS  eval_metrics/RMSE[mean]  eval_metrics/NRMSE[mean]  \
# 0           5.374672                53.780583                  0.195236
# 1          13.215153                10.075099                  0.615416
# 2           2.895807                 6.930978                  0.373597
# 3           8.949650                 8.475931                  0.513230
# 4           2.542028                 3.764300                  0.129281
#
#    eval_metrics/ND[0.5]  eval_metrics/mean_weighted_sum_quantile_loss  \
# 0              0.065603                                      0.051721
# 1              0.354589                                      0.318616
# 2              0.227030                                      0.180578
# 3              0.301900                                      0.265723
# 4              0.080625                                      0.066421
#
#          domain  num_variates
# 0    Healthcare             1
# 1  Web/CloudOps             7
# 2  Web/CloudOps             7
# 3  Web/CloudOps             7
# 4  Web/CloudOps             7

# %% [markdown]
# Display all of the results and only show the MASE and CRPS columns.

# %%
pd.set_option('display.max_rows', None)

df = df.rename(columns={
    "eval_metrics/MASE[0.5]": "MASE",
    "eval_metrics/mean_weighted_sum_quantile_loss": "CRPS",
},
errors="ignore",
)

keep_cols = [
    "dataset",
    "MASE",
    "CRPS",
    "domain",
    "num_variates",
]
df = df[keep_cols].sort_values(by="CRPS", ascending=False).reset_index(drop=True)
display(df)
# Out:
#                              dataset       MASE      CRPS        domain  \
# 0                  car_parts/M/short   0.880183  1.020970         Sales
# 1     bitbrains_fast_storage/5T/long   0.912993  0.773663  Web/CloudOps
# 2     bitbrains_fast_storage/H/short   1.040435  0.649417  Web/CloudOps
# 3            bitbrains_rnd/5T/medium   4.428266  0.642064  Web/CloudOps
# 4   bitbrains_fast_storage/5T/medium   0.999749  0.640577  Web/CloudOps
# 5              bitbrains_rnd/H/short   5.848796  0.637212  Web/CloudOps
# 6              bitbrains_rnd/5T/long   3.358888  0.626335  Web/CloudOps
# 7         hierarchical_sales/D/short   0.766172  0.612655         Sales
# 8           temperature_rain/D/short   1.414081  0.603111        Nature
# 9             bitbrains_rnd/5T/short   1.652894  0.398318  Web/CloudOps
# 10   bitbrains_fast_storage/5T/short   0.677921  0.389961  Web/CloudOps
# 11             kdd_cup_2018/H/medium   0.841162  0.376787        Nature
# 12               kdd_cup_2018/H/long   0.775086  0.374253        Nature
# 13              kdd_cup_2018/D/short   1.178567  0.370826        Nature
# 14        hierarchical_sales/W/short   0.734481  0.365086         Sales
# 15                   saugeen/W/short   1.172855  0.360401        Nature
# 16                   solar/10T/short   0.663585  0.350492        Energy
# 17                  solar/10T/medium   0.878348  0.342304        Energy
# 18                    solar/10T/long   0.899005  0.339926        Energy
# 19              kdd_cup_2018/H/short   0.807217  0.337506        Nature
# 20                   saugeen/D/short   2.642458  0.327655        Nature
# 21                     solar/D/short   1.081358  0.323054        Energy
# 22               bizitobs_l2c/H/long   0.615259  0.318616  Web/CloudOps
# 23                     solar/H/short   0.766041  0.309218        Energy
# 24                   saugeen/M/short   0.733121  0.308559        Nature
# 25                    solar/H/medium   0.762649  0.305832        Energy
# 26                      solar/H/long   0.750051  0.292837        Energy
# 27                      ett1/D/short   1.709526  0.282823        Energy
# 28              bizitobs_l2c/5T/long   0.571074  0.279806  Web/CloudOps
# 29                       ett1/H/long   1.381643  0.266980        Energy
# 30             bizitobs_l2c/H/medium   0.500909  0.265723  Web/CloudOps
# 31                restaurant/D/short   0.688139  0.262857         Sales
# 32                      ett1/W/short   1.553034  0.259446        Energy
# 33                     ett1/H/medium   1.262516  0.256087        Energy
# 34                     ett1/15T/long   1.032419  0.238577        Energy
# 35                   ett1/15T/medium   1.000498  0.237312        Energy
# 36            bizitobs_l2c/5T/medium   0.493990  0.222228  Web/CloudOps
# 37                sz_taxi/15T/medium   0.544760  0.209374     Transport
# 38                 sz_taxi/15T/short   0.544397  0.205125     Transport
# 39                  sz_taxi/15T/long   0.511142  0.200083     Transport
# 40                      ett1/H/short   0.830834  0.189972        Energy
# 41                     solar/W/short   1.328096  0.183687        Energy
# 42              bizitobs_l2c/H/short   0.414767  0.180578  Web/CloudOps
# 43                    ett1/15T/short   0.661964  0.151656        Energy
# 44                   sz_taxi/H/short   0.561322  0.135948     Transport
# 45                   m_dense/H/short   0.760884  0.124899     Transport
# 46                 m4_yearly/A/short   3.482621  0.119744      Econ/Fin
# 47                    m_dense/H/long   0.688223  0.113148     Transport
# 48                  m_dense/H/medium   0.673711  0.112133     Transport
# 49                       ett2/H/long   1.029421  0.102275        Energy
# 50                     ett2/H/medium   1.024832  0.101249        Energy
# 51                m4_monthly/M/short   0.938152  0.092548      Econ/Fin
# 52                      ett2/D/short   1.272625  0.091487        Energy
# 53                     ett2/15T/long   0.898063  0.091448        Energy
# 54                   ett2/15T/medium   0.878120  0.088697        Energy
# 55                electricity/H/long   1.088192  0.085715        Energy
# 56                      ett2/W/short   0.826107  0.082092        Energy
# 57             electricity/15T/short   0.880933  0.078659        Energy
# 58              loop_seattle/5T/long   0.853057  0.077024     Transport
# 59              m4_quarterly/Q/short   1.239394  0.076533      Econ/Fin
# 60            electricity/15T/medium   0.824595  0.075328        Energy
# 61              electricity/15T/long   0.874949  0.075326        Energy
# 62              electricity/H/medium   0.989781  0.072805        Energy
# 63            loop_seattle/5T/medium   0.788889  0.071152     Transport
# 64             bizitobs_l2c/5T/short   0.245052  0.066421  Web/CloudOps
# 65             loop_seattle/H/medium   0.924606  0.065836     Transport
# 66                      ett2/H/short   0.735188  0.063924        Energy
# 67                    ett2/15T/short   0.739756  0.063321        Energy
# 68               electricity/H/short   0.880764  0.062662        Energy
# 69                   m_dense/D/short   0.661422  0.062619     Transport
# 70               loop_seattle/H/long   0.888407  0.062410     Transport
# 71              loop_seattle/H/short   0.813166  0.058526     Transport
# 72               electricity/D/short   1.410644  0.056782        Energy
# 73               electricity/W/short   1.549426  0.056027        Energy
# 74               jena_weather/H/long   0.936824  0.055304        Nature
# 75              covid_deaths/D/short  40.866915  0.054530    Healthcare
# 76             jena_weather/H/medium   0.813949  0.052702        Nature
# 77     bizitobs_application/10S/long   3.297559  0.052540  Web/CloudOps
# 78                  hospital/M/short   0.765593  0.051721    Healthcare
# 79         bizitobs_service/10S/long   1.305549  0.051470  Web/CloudOps
# 80             jena_weather/10T/long   0.647970  0.049940        Nature
# 81           jena_weather/10T/medium   0.603623  0.047856        Nature
# 82             loop_seattle/5T/short   0.518805  0.044554     Transport
# 83              jena_weather/D/short   0.969810  0.044047        Nature
# 84              loop_seattle/D/short   0.861587  0.041759     Transport
# 85              jena_weather/H/short   0.509900  0.041035        Nature
# 86                 m4_weekly/W/short   2.034695  0.037545      Econ/Fin
# 87   bizitobs_application/10S/medium   2.210175  0.032999  Web/CloudOps
# 88            jena_weather/10T/short   0.290372  0.027894        Nature
# 89       bizitobs_service/10S/medium   1.041705  0.026416  Web/CloudOps
# 90                  m4_daily/D/short   3.264006  0.021768      Econ/Fin
# 91                 m4_hourly/H/short   0.800474  0.018980      Econ/Fin
# 92                 us_births/D/short   0.345879  0.018196    Healthcare
# 93                 us_births/M/short   0.733190  0.015068    Healthcare
# 94                 us_births/W/short   1.066406  0.012348    Healthcare
# 95    bizitobs_application/10S/short   1.212763  0.011104  Web/CloudOps
# 96        bizitobs_service/10S/short   0.778629  0.010808  Web/CloudOps
#
#     num_variates
# 0              1
# 1              2
# 2              2
# 3              2
# 4              2
# 5              2
# 6              2
# 7              1
# 8              1
# 9              2
# 10             2
# 11             1
# 12             1
# 13             1
# 14             1
# 15             1
# 16             1
# 17             1
# 18             1
# 19             1
# 20             1
# 21             1
# 22             7
# 23             1
# 24             1
# 25             1
# 26             1
# 27             7
# 28             7
# 29             7
# 30             7
# 31             1
# 32             7
# 33             7
# 34             7
# 35             7
# 36             7
# 37             1
# 38             1
# 39             1
# 40             7
# 41             1
# 42             7
# 43             7
# 44             1
# 45             1
# 46             1
# 47             1
# 48             1
# 49             7
# 50             7
# 51             1
# 52             7
# 53             7
# 54             7
# 55             1
# 56             7
# 57             1
# 58             1
# 59             1
# 60             1
# 61             1
# 62             1
# 63             1
# 64             7
# 65             1
# 66             7
# 67             7
# 68             1
# 69             1
# 70             1
# 71             1
# 72             1
# 73             1
# 74            21
# 75             1
# 76            21
# 77             2
# 78             1
# 79             2
# 80            21
# 81            21
# 82             1
# 83            21
# 84             1
# 85            21
# 86             1
# 87             2
# 88            21
# 89             2
# 90             1
# 91             1
# 92             1
# 93             1
# 94             1
# 95             2
# 96             2
